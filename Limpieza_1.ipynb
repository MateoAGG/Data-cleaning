# %% [markdown]
# # Limpieza de datos

# %%
import pandas as pd

# %%
dt = pd.read_csv('Bases\crime_incidents_messy.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\Mateo\AppData\Local\Temp\ipykernel_168712\2317367963.py:1: SyntaxWarning: invalid escape sequence '\c'
#   dt = pd.read_csv('Bases\crime_incidents_messy.csv')

# %%
dt['district'].unique()
# Out:
# <StringArray>
# [           'Sou',     ' southeast',    'Southwest  ',            'Cen',
#          ' North',         'East  ',      'southeast',        'midtown',
#       'northeast',        'CENTRAL',
#  ...
#   '  Northeast  ',      '   West  ',     '   North  ',            'eas',
#   '  northwest  ', '   Southeast  ',     '  West    ',    'southeast  ',
#             'mid',  '  northeast  ']
# Length: 131, dtype: str
